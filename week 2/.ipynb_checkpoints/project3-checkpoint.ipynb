# %%
import pandas as pd

# Girls data
girls_names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
girls_age = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
girls_height = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 5.5, 6.1, 6.0, 5.7]
girls_scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

# Boys data 
boys_names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
boys_age = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
# Fixed: Removed the accidental comma between 5 and 9; fixed the 61 typo to 6.1
boys_height = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
boys_scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

# Combine the lists
names = girls_names + boys_names
ages = girls_age + boys_age
heights = girls_height + boys_height
scores = girls_scores + boys_scores

# Create the DataFrame
# Fixed: Added the missing closing brace '}' and parenthesis ')'
data = pd.DataFrame({
    "Name": names,
    "Age": ages,
    "Height": heights,
    "Score": scores
})

print(data)
# Out:
#        Name  Age  Height  Score
# 0    Evelyn   17     5.5     80
# 1   Jessica   16     6.0     85
# 2     Somto   17     5.4     70
# 3     Edith   18     5.9     60
# 4      Liza   16     5.6     76
# 5   Madonna   18     5.5     66
# 6      Waje   17     5.5     87
# 7      Tola   20     6.1     95
# 8     Aisha   19     6.0     50
# 9    Latifa   17     5.7     49
# 10  Chinedu   19     5.7     74
# 11     Liam   16     5.9     87
# 12     Wale   18     5.8     75
# 13   Gbenga   17     6.1     68
# 14   Abiola   20     5.9     66
# 15     Kola   19     5.5     78
# 16    Kunle   16     6.1     87
# 17   George   18     5.4     98
# 18   Thomas   17     5.8     54
# 19   Wesley   19     5.7     60
