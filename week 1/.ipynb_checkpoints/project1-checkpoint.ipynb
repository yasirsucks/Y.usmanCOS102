# %%
# prgram to calculate these python program 
print("Select the problem you want to solve ")
print("1. Simple Interest")
print("2. Compound Interest")
print("3. Annuity Plan ")
      
problem = input("Input a number ")
if problem == "1":
    P = float(input("Input P"))
    R = float(input("Input R"))
    T = float(input("Input T"))
    A = P*(1+(R/100 )*T)
    print("Your SIMPLE INTEREST in ",A)
if problem == "2":
    P = float(input("Input P"))
    R = float(input("Input R"))
    T = float(input("Input T"))
    N = int(input("Input N"))
    CA = P*(1+(R/N)**T)
    print("Your COMPOUND INTEREST in ",CA)
if problem == "3":
    P = float(input("Input P"))
    M = float(input("Input M"))
    R = float(input("Input R"))
    T = float(input("Input T"))
    N = int(input("Input N"))
    AP = P*M*T * (((1+(R/N))**T)-1) / (R/N)
    print("Your ANNUITY PLAN in ",AP)

if problem >= "4":
    print("NOT A VALID OPTION")
# Out:
# Select the problem you want to solve
# 1. Simple Interest
# 2. Compound Interest
# 3. Annuity Plan
# Input a number  1
# Input P 2
# Input R 23
# Input T 3
# Your SIMPLE INTEREST in  3.38

# %%
# python program to print strings and type 
str1 = "himy name is matthew .i am string"
str2 = 'hi my name is precious . i am also a string '
#displaying string  str1 and its type 
print(str1)
print(type(str1))


#displaying string  str2 and its type 
print(str2)
print(type(str2))
# Out:
# himy name is matthew .i am string
# <class 'str'>
# hi my name is precious . i am also a string
# <class 'str'>

# %%
#integer 
num = 100
print(num)
print("data type of the variable is ", type(num))

#float 
fnum = 34.45
print(fnum)
print("data type of the variable fnum is ", type (fnum))

#complex number 
cnum = 3+4j
print(cnum)
print("data type of variable cnum is ",type (cnum))
# Out:
# 100
# data type of the variable is  <class 'int'>
# 34.45
# data type of the variable fnum is  <class 'float'>
# (3+4j)
# data type of variable cnum is  <class 'complex'>
